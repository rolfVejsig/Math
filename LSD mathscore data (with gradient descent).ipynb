# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import numpy as np

# %%
data = pd.read_csv('lsd_math_score_data.csv')

# %%
data
# Out:
#    Time_Delay_in_Minutes  LSD_ppm  Avg_Math_Test_Score
# 0                      5     1.17                78.93
# 1                     15     2.97                58.20
# 2                     30     3.26                67.47
# 3                     60     4.69                37.47
# 4                    120     5.83                45.65
# 5                    240     6.00                32.92
# 6                    480     6.41                29.97

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
time = data['Time_Delay_in_Minutes']
lsd = data['LSD_ppm']
score = data['Avg_Math_Test_Score']

# %%
plt.plot(lsd,score,color='#e74c3c',linewidth=3)

plt.title('Tissue concentration of LSD vs test score',fontsize=17)
plt.text(x=0,y=-0.5,s='Wagner et al. (1968)',fontsize=12)

plt.xlabel('LSD ppm')
plt.xticks(fontsize=14)
plt.xlim(1,7)

plt.ylabel('test scores')
plt.yticks(fontsize=14)
plt.ylim()

plt.style.use('classic')
plt.show()

# %%
time = data[['Time_Delay_in_Minutes']]
lsd = data[['LSD_ppm']]
score = data[['Avg_Math_Test_Score']]

# %%
regression = LinearRegression()
regression.fit(lsd,score)
predicted_score = regression.predict(lsd)

plt.plot(lsd.values,predicted_score,linewidth=3,c='r') 
plt.scatter(lsd,score,s=100, alpha = 0.7,c ='b')

plt.title('Arithmetic vs LSD-25',fontsize=17)

plt.xlabel('Tissue LSD ppm',fontsize=14)
plt.xlim(1,6.5)

plt.ylabel('Performance Score',fontsize=14)
plt.ylim(25,85)


plt.style.use('classic')
plt.show()

# %%
print("Theta0:",regression.intercept_[0])
print("Theta1:",regression.coef_[0][0])
print("R^2:",regression.score(lsd,score))
# Out:
# Theta0: 89.12387376799308
# Theta1: -9.009466415296785
# R^2: 0.8778349707775889

# %%
x = np.array(data['LSD_ppm'])
y = np.array(data['Avg_Math_Test_Score'])

# %%
def gradient_descent(x,y):
    m_curr = b_curr = 0
    iterations = 12000
    n = len(x)
    learning_rate = 0.01
    
    for i in range(iterations):
        y_predicted = m_curr* x + b_curr
        cost = (1/n)*sum([val**2 for val in (y-y_predicted)])
        md = -(2/n)*sum(x*(y-y_predicted))
        bd = -(2/n)*sum(y-y_predicted)
        m_curr = m_curr-learning_rate*md
        b_curr = b_curr-learning_rate*bd
    return m_curr,b_curr

# %%
gradient_descent(x,y)
# Out:
# (-9.009466415296297, 89.1238737679906)
