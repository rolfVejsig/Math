# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.DataFrame(np.random.randn(100, 2), columns=list('AB'))
df.min()
# Out:
# A   -3.035474
# B   -2.415261
# dtype: float64

# %%
sns.catplot(data=df,x='A',kind='violin')
