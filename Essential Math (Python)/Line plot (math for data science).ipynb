# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([69, 73, 78, 86,95,103,105,103,100,89,78,68])
xpoints = np.array(['Jan','feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'])

plt.plot(xpoints,ypoints)
plt.show()
